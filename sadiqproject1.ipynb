# %%
#  INDRODUCTION
#  iscover exceptional value and quality in our curated selection of pre-owned cars. Each vehicle has been meticulouslyinspected to ensure a reliable, high-performance driving experience. We offer a range of models from top brands like Mahindra, Hyundai, Tata, Honda, and Ford, featuring diverse options in transmission, fuel type, and engine capacity. Many of our vehicles are single-owner, well-maintained, and include features such as insurance and spare keys. Whether you’re looking for the rugged reliability of a Mahindra Thar or the elegance of a Honda City, our collection hassomething to match your driving needs and budget.

# %%
import pandas as pd
df=pd.read_csv(r"C:\Data science(sadiq)\pre-owned cars.csv")
df.describe()
# Out:
#          make_year  engine_capacity(CC)      km_driven         price  \
# count  2805.000000          2688.000000    2805.000000  2.806000e+03
# mean   2018.181105          1259.027530   49215.477362  1.342522e+06
# std       2.945293           254.504798   26626.932696  3.554669e+07
# min    2010.000000           624.000000     450.000000  1.630000e+05
# 25%    2016.000000          1194.000000   28540.000000  4.350000e+05
# 50%    2018.000000          1197.000000   45695.000000  5.940000e+05
# 75%    2021.000000          1462.000000   68182.000000  8.140000e+05
# max    2024.000000          2694.000000  143991.000000  1.883558e+09
#
#        overall_cost
# count   2805.000000
# mean   13495.022816
# std     6040.809220
# min     4039.000000
# 25%     9267.000000
# 50%    12145.000000
# 75%    15760.000000
# max    47338.000000

# %%
for i in df:
    j=i.replace(' ','_')
    df=df.rename(columns={i:j.capitalize()})
    df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2806 entries, 0 to 2805
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                2805 non-null   object
#  1   Model                2805 non-null   object
#  2   Transmission         2805 non-null   object
#  3   Make_year            2805 non-null   float64
#  4   Reg_year             720 non-null    object
#  5   Fuel_type            2805 non-null   object
#  6   Engine_capacity(cc)  2688 non-null   float64
#  7   Km_driven            2805 non-null   float64
#  8   Ownership            2805 non-null   object
#  9   Price                2806 non-null   int64
#  10  Overall_cost         2805 non-null   float64
#  11  Has_insurance        2805 non-null   object
#  12  Spare_key            2805 non-null   object
#  13  Reg_number           2805 non-null   object
#  14  Title                2805 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Brand                     1
# Model                     1
# Transmission              1
# Make_year                 1
# Reg_year               2086
# Fuel_type                 1
# Engine_capacity(cc)     118
# Km_driven                 1
# Ownership                 1
# Price                     0
# Overall_cost              1
# Has_insurance             1
# Spare_key                 1
# Reg_number                1
# Title                     1
# dtype: int64

# %%
columns_to_fill = ['Overall_cost','Reg_year','Reg_number','Engine_capacity(cc)',
                   'Title','Spare_key','Has_insurance','Ownership','Km_driven',
                   'Fuel_type','Make_year','Transmission','Model','Brand'] 

for column in columns_to_fill:
    df[column].fillna(df[column].mode()[0], inplace=True)

print(df[columns_to_fill].isnull().sum())
# Out:
# Overall_cost           0
# Reg_year               0
# Reg_number             0
# Engine_capacity(cc)    0
# Title                  0
# Spare_key              0
# Has_insurance          0
# Ownership              0
# Km_driven              0
# Fuel_type              0
# Make_year              0
# Transmission           0
# Model                  0
# Brand                  0
# dtype: int64
# C:\Users\hp\AppData\Local\Temp\ipykernel_16796\2160717055.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %% [markdown]
# #### Identifying the most preferred car brand in India

# %%
#1.What is the most frequent car brand?

most_frequent_brand = df['Brand'].value_counts().idxmax()
print(most_frequent_brand)
# Out:
# Maruti

# %%
import matplotlib.pyplot as plt

brand_counts = df['Brand'].value_counts()

plt.figure(figsize=(10, 6))
brand_counts.plot(kind='bar', color='brown')
plt.title('Frequency of Car Brands in the Dataset', fontsize=16)
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#CONCLUSION

#The most frequent car brand in the dataset is Maruti

# %%
#2.Which is the  most common car models i

most_common_models = df['Model'].value_counts().head(10)  # Get the top 10 most common models
print(most_common_models)
# Out:
# Model
# Baleno DELTA PETROL 1.2            49
# Swift VXI                          46
# Grand i10 SPORTZ 1.2 KAPPA VTVT    45
# Baleno ZETA PETROL 1.2             38
# Wagon R 1.0 VXI                    32
# Amaze 1.2L I-VTEC S                30
# City 1.5L I-VTEC V MT              30
# Wagon R 1.0 LXI CNG                25
# Celerio ZXI AMT                    24
# Alto K10 VXI                       23
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get the top 10 most common car models
most_common_models = df['Model'].value_counts().head(10)

# Plot the data
plt.figure(figsize=(10, 6))
sns.barplot(x=most_common_models.values,y=most_common_models.index,palette='magma')
plt.title('Top 10 Most Common Car Models', fontsize=16)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Model', fontsize=12)
plt.gca().invert_yaxis()  # Invert y-axis to have the most common model at the top
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16796\2980190251.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=most_common_models.values,y=most_common_models.index,palette='magma')

# %%
# conclusion 

#The most common car model in the dataset is Baleno DELTA PETROL 1.2.

# %%
#3. What percentage of cars have manual transmission vs automatic transmission?

transmission_counts = df['Transmission'].value_counts(normalize=True) * 100
print(transmission_counts)
# Out:
# Transmission
# Manual       68.638632
# Automatic    31.361368
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

# Calculate the percentage of manual and automatic transmissions
transmission_counts = df['Transmission'].value_counts(normalize=True) * 100

# Plot the data
plt.figure(figsize=(6, 6))
transmission_counts.plot(kind='pie', autopct='%1.1f%%', colors=['grey', 'brown'])
plt.title('Percentage of Manual vs Automatic Transmission', fontsize=16)
plt.ylabel('')  # Hide the y-label for better presentation
plt.tight_layout()
plt.show()

# %%
# based on this data set , manual transmssion  has 68.6% and automatic transmission  has 31.4%

# %%
#4. What is the distribution of cars by fuel type ?
fuel_type_distribution = df['Fuel_type'].value_counts()


print(fuel_type_distribution)
# Out:
# Fuel_type
# Petrol      2374
# Diesel       318
# CNG          110
# Electric       4
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

brand_counts = df['Fuel_type'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=brand_counts.index, y=brand_counts.values, palette='magma')
plt.title('Frequency of Car Brands in the Dataset', fontsize=16)
plt.xlabel('Fuel_type', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16796\942720871.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=brand_counts.index, y=brand_counts.values, palette='magma')

# %%
#CONCLUTION
 
#The most distributed cars by fuel type is petrol.

# %%
#5.Which car model has the highest km driven, and what are its details? 

import pandas as pd 

car_highest_km = df.loc[df['Km_driven'].idxmax()]

car_highest_km_details = {
    'Brand': car_highest_km['Brand'],
    'Model': car_highest_km['Model'],
    'Transmission': car_highest_km['Transmission'],
    'Make Year': car_highest_km['Make_year'],
    'Fuel Type': car_highest_km['Fuel_type'],
    'Engine Capacity (CC)': car_highest_km['Engine_capacity(cc)'],
    'Kilometers Driven': car_highest_km['Km_driven'],
    'Ownership': car_highest_km['Ownership'],
    'Price': car_highest_km['Price'],
    'Overall Cost': car_highest_km['Overall_cost'],
    'Has Insurance': car_highest_km['Has_insurance'],
    'Spare Key': car_highest_km['Spare_key'],
    'Registration Number': car_highest_km['Reg_number']
}

car_highest_km_details
# Out:
# {'Brand': 'Honda',
#  'Model': 'Brio S(O) MT',
#  'Transmission': 'Manual',
#  'Make Year': np.float64(2012.0),
#  'Fuel Type': 'Petrol',
#  'Engine Capacity (CC)': np.float64(1198.0),
#  'Kilometers Driven': np.float64(143991.0),
#  'Ownership': '1st owner',
#  'Price': np.int64(269000),
#  'Overall Cost': np.float64(8935.0),
#  'Has Insurance': np.True_,
#  'Spare Key': 'No',
#  'Registration Number': 'KA51'}

# %%
import matplotlib.pyplot as plt

car_highest_km_details = {
    'Brand': car_highest_km['Brand'],
    'Model': car_highest_km['Model'],
    'Kilometers Driven': car_highest_km['Km_driven'],
    'Price': car_highest_km['Price'],
    'Overall Cost': car_highest_km['Overall_cost'],
    'Engine Capacity (CC)': car_highest_km['Engine_capacity(cc)'],
}
labels = ['Kilometers Driven', 'Price', 'Overall Cost', 'Engine Capacity (CC)']
values = [car_highest_km_details['Kilometers Driven'], car_highest_km_details['Price'], 
          car_highest_km_details['Overall Cost'], car_highest_km_details['Engine Capacity (CC)']]
plt.figure(figsize=(8, 5))
plt.bar(labels, values, color=['grey', 'brown', 'black', 'grey'])
plt.title(f"Car with Highest Kilometers Driven: {car_highest_km_details['Brand']} {car_highest_km_details['Model']}")
plt.ylabel("Values")
plt.show()

# %%
#Conclusion

#The highest km driven car model is Honda 'Brio S(O) MT'.

# %%
#6.What is the average km driven by cars of each brand? 

import pandas as pd 

average_km_by_brand = df.groupby('Brand')['Km_driven'].mean().reset_index()
average_km_by_brand.columns = ['Brand', 'Average Kilometers Driven']
average_km_by_brand = average_km_by_brand.sort_values(by='Average Kilometers Driven', ascending=False)
average_km_by_brand
# Out:
#          Brand  Average Kilometers Driven
# 1         Ford               61876.515625
# 2        Honda               59341.289855
# 14  Volkswagen               59144.792453
# 4         Jeep               57215.333333
# 11       Skoda               54211.212121
# 3      Hyundai               53640.715152
# 13      Toyota               52731.388889
# 8       Maruti               50020.123110
# 0       Datsun               43656.117647
# 9       Nissan               41681.157895
# 7     Mahindra               41286.210526
# 12        Tata               37623.408333
# 10     Renault               37070.443114
# 5          KIA               36705.456897
# 6           MG               33935.810811

# %%
import matplotlib.pyplot as plt

average_km_by_brand = df.groupby('Brand')['Km_driven'].mean().reset_index()
average_km_by_brand.columns = ['Brand', 'Average Kilometers Driven']
average_km_by_brand = average_km_by_brand.sort_values(by='Average Kilometers Driven', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(average_km_by_brand['Brand'], average_km_by_brand['Average Kilometers Driven'], color='grey')
plt.xlabel('Average Kilometers Driven')
plt.ylabel('Brand')
plt.title('Average Kilometers Driven by Car Brand')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Conclusion 

# The average km driven by cars of each brand is over 30000KM.

# %%
#7. Which car model has the highest overall cost (price + overall maintenance cost)?
df['Total_cost'] = df['Price'] + df['Overall_cost']
car_highest_total_cost = df.loc[df['Total_cost'].idxmax()]

car_highest_total_cost_details = {
    'Brand': car_highest_total_cost['Brand'],
    'Model': car_highest_total_cost['Model'],
    'Transmission': car_highest_total_cost['Transmission'],
    'Make Year': car_highest_total_cost['Make_year'],
    'Fuel Type': car_highest_total_cost['Fuel_type'],
    'Engine Capacity (CC)': car_highest_total_cost['Engine_capacity(cc)'],
    'Kilometers Driven': car_highest_total_cost['Km_driven'],
    'Ownership': car_highest_total_cost['Ownership'],
    'Price': car_highest_total_cost['Price'],
    'Overall Maintenance Cost': car_highest_total_cost['Overall_cost'],
    'Total Cost (Price + Maintenance)': car_highest_total_cost['Total_cost'],
    'Has Insurance': car_highest_total_cost['Has_insurance'],
    'Spare Key': car_highest_total_cost['Spare_key'],
    'Registration Number': car_highest_total_cost['Reg_number']
}

car_highest_total_cost_details
# Out:
# {'Brand': 'Maruti',
#  'Model': 'Baleno DELTA PETROL 1.2',
#  'Transmission': 'Manual',
#  'Make Year': np.float64(2017.0),
#  'Fuel Type': 'Petrol',
#  'Engine Capacity (CC)': np.float64(1197.0),
#  'Kilometers Driven': np.float64(27603.0),
#  'Ownership': '1st owner',
#  'Price': np.int64(1883558000),
#  'Overall Maintenance Cost': np.float64(7879.0),
#  'Total Cost (Price + Maintenance)': np.float64(1883565879.0),
#  'Has Insurance': np.True_,
#  'Spare Key': 'No',
#  'Registration Number': 'KA05'}

# %%
import matplotlib.pyplot as plt

df['Total_cost'] = df['Price'] + df['Overall_cost']

car_highest_total_cost = df.loc[df['Total_cost'].idxmax()]

labels = ['Price', 'Overall Maintenance Cost', 'Total Cost']
values = [car_highest_total_cost['Price'], car_highest_total_cost['Overall_cost'], car_highest_total_cost['Total_cost']]
plt.figure(figsize=(8, 5))
plt.bar(labels, values, color=['grey', 'lightgreen', 'brown'])
plt.title(f"Car with Highest Overall Cost: {car_highest_total_cost['Brand']} {car_highest_total_cost['Model']}")
plt.ylabel("Cost (in currency units)")
plt.tight_layout()
plt.show()

# %%
#CONCLUSION 

##Based on the dataset, the highest overall cost (price + overall maintenance cost) car is Maruthi 'Baleno DELTA PETROL 1.2'.

# %%
# 8 Which car has the lowest price, and what are its key characteristics? 
car_lowest_price = df.loc[df['Price'].idxmin()]

car_lowest_price_details = {
    'Brand': car_lowest_price['Brand'],
    'Model': car_lowest_price['Model'],
    'Transmission': car_lowest_price['Transmission'],
    'Make Year': car_lowest_price['Make_year'],
    'Fuel Type': car_lowest_price['Fuel_type'],
    'Engine Capacity (CC)': car_lowest_price['Engine_capacity(cc)'],
    'Kilometers Driven': car_lowest_price['Km_driven'],
    'Ownership': car_lowest_price['Ownership'],
    'Price': car_lowest_price['Price'],
    'Overall Cost': car_lowest_price['Overall_cost'],
    'Has Insurance': car_lowest_price['Has_insurance'],
    'Spare Key': car_lowest_price['Spare_key'],
    'Registration Number': car_lowest_price['Reg_number']
}

car_lowest_price_details
# Out:
# {'Brand': 'Maruti',
#  'Model': 'Wagon R 1.0 LX',
#  'Transmission': 'Manual',
#  'Make Year': np.float64(2011.0),
#  'Fuel Type': 'Petrol',
#  'Engine Capacity (CC)': np.float64(998.0),
#  'Kilometers Driven': np.float64(93282.0),
#  'Ownership': '1st owner',
#  'Price': np.int64(163000),
#  'Overall Cost': np.float64(7664.0),
#  'Has Insurance': np.True_,
#  'Spare Key': 'Yes',
#  'Registration Number': 'DL3C'}

# %%
import matplotlib.pyplot as plt

car_lowest_price = df.loc[df['Price'].idxmin()]

labels = ['Price', 'Overall Cost', 'Kilometers Driven']
values = [car_lowest_price['Price'], car_lowest_price['Overall_cost'], car_lowest_price['Km_driven']]

plt.figure(figsize=(8, 5))
plt.bar(labels, values, color=['black', 'grey', 'silver'])
plt.title(f"Car with the Lowest price: {car_lowest_price['Brand']} {car_lowest_price['Model']}")
plt.ylabel("Values")
plt.tight_layout()
plt.show()

# %%
# CONCLUTION 

#Based on the dataset,The lowest price car is Maruti Wagon R 1.0 LX.

# %%
#9.What is the distribution of engine capacity (CC) for different brands?

engine_capacity_distribution = df.groupby('Brand')['Engine_capacity(cc)'].describe()

engine_capacity_distribution
# Out:
#             count         mean         std     min     25%     50%      75%  \
# Brand
# Datsun       34.0   992.735294  166.376956   799.0   799.0   999.0  1197.75
# Ford         64.0  1450.718750  110.701152  1194.0  1497.0  1498.0  1498.25
# Honda       276.0  1352.231884  153.881408  1197.0  1199.0  1497.0  1497.00
# Hyundai     660.0  1259.895455  202.230730   814.0  1197.0  1197.0  1396.00
# Jeep         12.0  1647.750000  325.378695  1197.0  1368.0  1662.0  1956.00
# KIA         116.0  1340.034483  190.904571   998.0  1197.0  1353.0  1493.00
# MG           37.0  1532.810811  215.159222  1197.0  1451.0  1451.0  1451.00
# Mahindra    114.0  1795.850877  423.644559  1197.0  1198.0  1997.0  2179.00
# Maruti      926.0  1159.178186  164.022060   796.0   998.0  1197.0  1197.00
# Nissan       38.0  1079.289474  139.815691   999.0   999.0   999.0  1198.00
# Renault     167.0  1073.011976  192.332794   799.0   999.0   999.0   999.00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x='Brand', y='Engine_capacity(cc)', data=df,palette='magma')
plt.title('Distribution of Engine Capacity (CC) for Different Brands')
plt.xlabel('Brand')
plt.ylabel('Engine Capacity (CC)')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16796\4240923759.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Brand', y='Engine_capacity(cc)', data=df,palette='magma')

# %%
#CONCLUSION

# The engine capacity (CC) varies significantly across different car brands. Some brands tend to have cars with larger engines, while others focus more on smaller engine capacities.

# %%
#10.How many cars are being sold by their 1st owners?

first_owner_cars_count = df[df['Ownership'] == '1st owner'].shape[0]
print(first_owner_cars_count)
# Out:
# 2046

# %%
import matplotlib.pyplot as plt

ownership_counts = df['Ownership'].value_counts()

plt.figure(figsize=(8, 6))
ownership_counts.plot(kind='bar', color=['grey', 'brown'])
plt.title('Number of Cars by Ownership Type', fontsize=16)
plt.xlabel('Ownership Type', fontsize=14)
plt.ylabel('Number of Cars', fontsize=14)
plt.xticks(rotation=0)
plt.show()

# %%
#CONCLUSION 

# Majority 1st Owners The dataset shows that a large number of the cars are being sold by their 1st owners.

# %%
#TOTAL CONCLUSION

#This dataset provides a comprehensive overview of 2,806 pre-owned cars, with each entry detailing essential characteristics such as brand, model, transmission type, and the year of manufacture. Additional information includes the type of fuel used, engine capacity, kilometers driven, and ownership history, which indicate whether the car is a first-owner vehicle or not. Price details, including the overall cost associated with each car, allow for a better understanding of the financial aspects of owning these vehicles. Some additional indicators, like whether the car has insurance or a spare key, and registration information, offer insights into each car's current status and readiness for resale. Although registration year data is missing in a significant portion of the dataset, there is still ample information for analysis
